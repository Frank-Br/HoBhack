# %% [markdown]
# <a href="https://colab.research.google.com/github/Frank-Br/HoBhack/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas
import pandas as pd
import numpy as np

# %%
# Importeer de csv
df = pd.read_csv("/content/movies.csv")

# %%
# Data exploratie, eerste indruk van de dataset
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df['score'].mean()
# Out:
# 6.390410958904098

# %%
df['director'].describe()
# Out:
# count            7668
# unique           2949
# top       Woody Allen
# freq               38
# Name: director, dtype: object

# %%
df[df['director'] == 'Woody Allen']['score'].mean()
# Out:
# 6.973684210526316

# %%
df.groupby['genre']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-bce620185221> in <module>()
# ----> 1 df.groupby['genre']
#
# TypeError: 'method' object is not subscriptable

# %%
profit = df['gross'] - df['budget']

# %%
df['profit'] = df['gross'] - df['budget']

# %%
df['profit']
# Out:
# 0        27998772.0
# 1        54353106.0
# 2       520375067.0
# 3        79953539.0
# 4        33846344.0
#            ...
# 7663            NaN
# 7664            NaN
# 7665            NaN
# 7666            NaN
# 7667            NaN
# Name: profit, Length: 7668, dtype: float64

# %%
profitdf = df[['genre','profit']]
profitdf
# Out:
#           genre       profit
# 0         Drama   27998772.0
# 1     Adventure   54353106.0
# 2        Action  520375067.0
# 3        Comedy   79953539.0
# 4        Comedy   33846344.0
# ...         ...          ...
# 7663      Drama          NaN
# 7664     Comedy          NaN
# 7665      Drama          NaN
# 7666      Drama          NaN
# 7667     Horror          NaN
#
# [7668 rows x 2 columns]

# %%
variabele = profitdf.groupby(['genre']).mean()

# %%
profitdf.groupby(['genre']).count()
# Out:
#            profit
# genre
# Action       1417
# Adventure     327
# Animation     278
# Biography     312
# Comedy       1496
# Crime         400
# Drama         869
# Family          4
# Fantasy        42
# History         0
# Horror        254
# Music           0
# Musical         0
# Mystery        17
# Romance         5
# Sci-Fi          6
# Sport           0
# Thriller        7
# Western         2

# %%
stardf = df[['star', 'score']]
stardf2 = stardf.groupby(['star']).mean()
sorted_stardf = stardf2.sort_values(by='score', ascending=False)
print(sorted_stardf)
# Out:
#                      score
# star
# Alexandre Rodrigues    8.6
# Luigi Lo Cascio        8.5
# Mark Hamill            8.5
# Kay Kay Menon          8.5
# Philippe Noiret        8.5
# ...                    ...
# Paris Hilton           1.9
# Carmen Electra         1.9
# Billy Hartmann         NaN
# Christina Roz          NaN
# Nicky Whelan           NaN
#
# [2814 rows x 1 columns]

# %%
table = [1,2,3]
df(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-bb1da00a37c1> in <module>()
#       1 table = [1,2,3]
# ----> 2 df(table)
#
# TypeError: 'DataFrame' object is not callable

# %%
variabele[variabele['profit']]==variabele['profit'].max()]
# Out:
#               profit
# genre
# Family  4.674581e+08

# %%
df['score'].describe()
# Out:
# count    7665.000000
# mean        6.390411
# std         0.968842
# min         1.900000
# 25%         5.800000
# 50%         6.500000
# 75%         7.100000
# max         9.300000
# Name: score, dtype: float64

# %%
df.query("score == 1.9")
# Out:
#                               name rating   genre  year  \
# 4594  Superbabies: Baby Geniuses 2     PG  Comedy  2004
# 5306                Disaster Movie  PG-13  Comedy  2008
# 5354       The Hottie & the Nottie  PG-13  Comedy  2008
#
#                              released  score    votes         director  \
# 4594  August 27, 2004 (United States)    1.9  30000.0        Bob Clark
# 5306  August 29, 2008 (United States)    1.9  88000.0  Jason Friedberg
# 5354       February 21, 2008 (Russia)    1.9  36000.0       Tom Putnam
#
#                writer            star        country      budget       gross  \
# 4594  Robert Grasmere      Jon Voight        Germany  20000000.0   9448644.0
# 5306  Jason Friedberg  Carmen Electra  United States  20000000.0  34816824.0
# 5354     Heidi Ferrer    Paris Hilton  United States         NaN   1596232.0
#
#                        company  runtime      profit
# 4594  ApolloMedia Distribution     88.0 -10551356.0
# ...
